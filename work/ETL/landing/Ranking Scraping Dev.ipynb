# %%
from scraping import get_soup,find_all,find
import pandas as pd

# %%
soup = get_soup(url="https://www.curlingzone.com/rankings.php?task=week&oomid=81&eventyear=2021#1")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.curlingzone.com/talk/xmlrpc.php" rel="pingback"/>
# <meta content="summary_large_image" name="twitter:card">
# <meta content="@curlingzone" name="twitter:site">
# <meta content="@guertez" name="twitter:creator"/>
# <title>CurlingZone – Everything Curling</title>
# <link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://www.curlingzone.com/?feed=rss2" rel="alternate" title="CurlingZone » Feed" type="application/rss+xml"/>
# <link href="https://www.curlingzone.com/?feed=comments-rss2" rel="alternate" title="CurlingZone » Comments Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.curlingzone.com\/talk\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.7.5"}};
# 			!function(a,b,c){function d(a){var b,c,d,e,f=String.fromCharCode;if(!k||!k.fillText)return!1;switch(k.clearRect(0,0,j.width,j.height),k.textBaseline="top",k.font="600 32px Arial",a){case"flag":return k.fillText(f(55356,56826,55356,56819),0,0),!(j.toDataURL().length<3e3)&&(k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,65039,8205,55356,57096),0,0),b=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,55356,57096),0,0),c=j.toDataURL(),b!==c);case"emoji4":return k.fillText(f(55357,56425,55356,57341,8205,55357,56507),0,0),d=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55357,56425,55356,57341,55357,56507),0,0),e=j.toDataURL(),d!==e}return!1}function e(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g,h,i,j=b.createElement("canvas"),k=j.getContext&&j.getContext("2d");for(i=Array("flag","emoji4"),c.supports={everything:!0,everythingExceptFlag:!0},h=0;h<i.length;h++)c.supports[i[h]]=d(i[h]),c.supports.everything=c.supports.everything&&c.supports[i[h]],"flag"!==i[h]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[i[h]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.curlingzone.com/css/style.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/css/responsive.css" media="all" rel="stylesheet" type="text/css">
# <link href="https://www.curlingzone.com/css/brackets.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-includes/css/dashicons.min.css?ver=4.7.5" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-includes/css/admin-bar.min.css?ver=4.7.5" id="admin-bar-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/captcha/css/front_end_style.css?ver=4.3.0" id="cptch_stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/captcha/css/desktop_style.css?ver=4.3.0" id="cptch_desktop_style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/css/font-awesome.min.css?ver=1.0.4" id="smls-fontawesome-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans%3A400%2C300%2C600%2C700%2C800&amp;ver=4.7.5" id="smls-google-fonts-sans-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto%3A400%2C300italic%2C400italic%2C500%2C500italic%2C700%2C700italic%2C900italic%2C900&amp;ver=4.7.5" id="smls-google-fonts-roboto-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Lato%3A400%2C300italic%2C400italic%2C700%2C700italic%2C900italic%2C900&amp;ver=4.7.5" id="smls-google-fonts-lato-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Montserrat%3A400%2C700&amp;ver=4.7.5" id="smls-google-fonts-montserrat-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Merriweather+Sans%3A300%2C400%2C700%2C800+Sans%3A300%2C400%2C700&amp;ver=4.7.5" id="smls-google-fonts-merriweather-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Droid+Sans%3A400%2C700&amp;ver=4.7.5" id="smls-google-fonts-droid-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Oxygen%3A300%2C400%2C700&amp;ver=4.7.5" id="smls-google-fonts-oxygen-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Raleway%3A100%2C200%2C300%2C400%2C500%2C600%2C700%2C800%2C900&amp;ver=4.7.5" id="smls-google-fonts-raleway-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/css/owl.carousel.css?ver=1.0.4" id="smls-owl-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/css/tooltipster.bundle.css?ver=1.0.4" id="smls-tooltip-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/css/smls-frontend-style.css?ver=1.0.4" id="smls-frontend-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/css/smls-responsive.css?ver=1.0.4" id="smls-responsive-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.curlingzone.com/talk/wp-content/plugins/woocommerce/assets/css/woocommerce-layout.css?ver=3.0.7" id="woocommerce-layout-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.curlingzone.com/talk/wp-content/plugins/woocommerce/assets/css/woocommerce-smallscreen.css?ver=3.0.7" id="woocommerce-smallscreen-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="//www.curlingzone.com/talk/wp-content/plugins/woocommerce/assets/css/woocommerce.css?ver=3.0.7" id="woocommerce-general-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/css/bootstrap.min.css?ver=4.7.5" id="bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/css/bootstrap-responsive.min.css?ver=4.7.5" id="bootstrap-responsive-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/css/prettyphoto.css?ver=4.7.5" id="prettyPhoto-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/style.css?ver=4.7.5" id="ct-style-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/css/options.css?ver=4.7.5" id="ct-custom-options-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=PT+Sans%3A400%2C400italic%2C700italic%2C700&amp;ver=4.7.5" id="ct-opensans-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.curlingzone.com/talk/wp-content/plugins/youtube-embed-plus/styles/ytprefs.min.css?ver=4.7.5" id="__EPYT__style-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="__EPYT__style-inline-css" type="text/css">
#
#                 .epyt-gallery-thumb {
#                         width: 33.333%;
#                 }
#
# </style>
# <script src="https://www.curlingzone.com/talk/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <!--[if lt IE 8]>
# <script type='text/javascript' src='https://www.curlingzone.com/talk/wp-includes/js/json2.min.js?ver=2015-05-03'></script>
# <![endif]-->
# <script type="text/javascript">
# /* <![CDATA[ */
# var live_blogging = {"ajaxurl":"http:\/\/www.curlingzone.com\/talk\/wp-admin\/admin-ajax.php","update_effect":"top"};
# /* ]]> */
# </script>
# <script src="https://www.curlingzone.com/talk/wp-content/plugins/live-blogging/live-blogging.min.js?ver=4.7.5" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/js/owl.carousel.js?ver=1.0.4" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/js/tooltipster.bundle.js?ver=1.0.4" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/plugins/smart-logo-showcase-lite/js/smls-frontend-script.js?ver=1.0.4" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var _EPYT_ = {"ajaxurl":"http:\/\/www.curlingzone.com\/talk\/wp-admin\/admin-ajax.php","security":"210f01f09f","gallery_scrolloffset":"20","eppathtoscripts":"http:\/\/www.curlingzone.com\/talk\/wp-content\/plugins\/youtube-embed-plus\/scripts\/","epresponsiveselector":"[\"iframe.__youtube_prefs_widget__\"]","epdovol":"1","version":"11.8","evselector":"iframe.__youtube_prefs__[src], iframe[src*=\"youtube.com\/embed\/\"], iframe[src*=\"youtube-nocookie.com\/embed\/\"]","ajax_compat":"","stopMobileBuffer":"1"};
# /* ]]> */
# </script>
# <script src="https://www.curlingzone.com/talk/wp-content/plugins/youtube-embed-plus/scripts/ytprefs.min.js?ver=4.7.5" type="text/javascript"></script>
# <link href="https://www.curlingzone.com/?rest_route=/" rel="https://api.w.org/"/>
# <link href="https://www.curlingzone.com/talk/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.curlingzone.com/talk/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 4.7.5" name="generator"/>
# <meta content="WooCommerce 3.0.7" name="generator"/>
# <noscript><style>.woocommerce-product-gallery{ opacity: 1 !important; }</style></noscript>
# <style media="print" type="text/css">#wpadminbar { display:none; }</style>
# <style media="screen" type="text/css">
# 	html { margin-top: 32px !important; }
# 	* html body { margin-top: 32px !important; }
# 	@media screen and ( max-width: 782px ) {
# 		html { margin-top: 46px !important; }
# 		* html body { margin-top: 46px !important; }
# 	}
# </style>
# <link href="https://www.curlingzone.com/talk/wp-content/uploads/2016/05/cropped-logo_main_new-32x32.gif" rel="icon" sizes="32x32"/>
# <link href="https://www.curlingzone.com/talk/wp-content/uploads/2016/05/cropped-logo_main_new-192x192.gif" rel="icon" sizes="192x192"/>
# <link href="https://www.curlingzone.com/talk/wp-content/uploads/2016/05/cropped-logo_main_new-180x180.gif" rel="apple-touch-icon-precomposed"/>
# <meta content="https://www.curlingzone.com/talk/wp-content/uploads/2016/05/cropped-logo_main_new-270x270.gif" name="msapplication-TileImage"/>
# <!-- Hotjar Tracking Code for www.curlingzone.com -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:866729,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
# <script type="text/javascript">
#   window._taboola = window._taboola || [];
#   _taboola.push({article:'auto'});
#   !function (e, f, u) {
#     e.async = 1;
#     e.src = u;
#     f.parentNode.insertBefore(e, f);
#   }(document.createElement('script'),
#   document.getElementsByTagName('script')[0],
#   '//cdn.taboola.com/libtrc/curlingzone/loader.js');
# </script><script language="JavaScript">
#     function scorepop()
#     {
#     win3 = window.open('https://www.curlingzone.com/forums/scores/scorepop.php','mywindow','centered,left=0,top=0,width=320,height=430,scrollbars=yes,menubar=no,resizable=no,toolbar=no');
#     if (win3 && win3.open && !win3.closed)win3.window.focus();
#     }
#
#     function scoreb(gametype, tgameid, tournamentid)
#     {
#     win3 = window.open('https://www.curlingzone.com/forums/scores/index.php?tournamentgameid='+tgameid+'&tournamentid='+tournamentid, 'GameScore', 'centered,left=0,top=0,width=810,height=620,scrollbars=yes,menubar=no,resizable=yes,toolbar=no');
#     if (win3 && win3.open && !win3.closed)win3.window.focus();
#     }
#     function scorea(tournamentid, tgameid, gamelinkid, gameid, teamid1, teamid2, drawid)
#     {
#     win3 = window.open('https://www.curlingzone.com/forums/scores/index.php?tournamentid='+tournamentid+'&tournamentgameid='+tgameid+'&gamelinkid='+gamelinkid+'&gameid='+gameid+'&teamid1='+teamid1+'&teamid2='+teamid2+'&drawid='+drawid, 'GameScore', 'centered,left=0,top=0,width=810,height=620,scrollbars=yes,menubar=no,resizable=yes,toolbar=no');
#     if (win3 && win3.open && !win3.closed)win3.window.focus();
#     }
#     function stats(tournamentid, tgameid, gamelinkid, gameid, teamid1, teamid2, drawid)
#     {
#     win3 = window.open('https://www.curlingzone.com/forums/scores/statistics.php?tournamentid='+tournamentid+'&tournamentgameid='+tgameid+'&gamelinkid='+gamelinkid+'&gameid='+gameid+'&teamid1='+teamid1+'&teamid2='+teamid2+'&drawid='+drawid, 'GameScore', 'centered,left=0,top=0,width=810,height=620,scrollbars=yes,menubar=no,resizable=yes,toolbar=no');
#     if (win3 && win3.open && !win3.closed)win3.window.focus();
#     }
# 	function bios(tournamentid, tgameid, gamelinkid, gameid, teamid1, teamid2, drawid)
#     {
#     win3 = window.open('https://www.curlingzone.com/forums/scores/bios.php?tournamentid='+tournamentid+'&tournamentgameid='+tgameid+'&gamelinkid='+gamelinkid+'&gameid='+gameid+'&teamid1='+teamid1+'&teamid2='+teamid2+'&drawid='+drawid, 'GameScore', 'centered,left=0,top=0,width=810,height=620,scrollbars=yes,menubar=no,resizable=yes,toolbar=no');
#     if (win3 && win3.open && !win3.closed)win3.window.focus();
#     }
#     function tactics(tournamentid, tgameid, gamelinkid, gameid, teamid1, teamid2, drawid)
#     {
#     win3 = window.open('https://www.curlingzone.com/forums/scores/tactics.php?tournamentid='+tournamentid+'&tournamentgameid='+tgameid+'&gamelinkid='+gamelinkid+'&gameid='+gameid+'&teamid1='+teamid1+'&teamid2='+teamid2+'&drawid='+drawid, 'GameScore', 'centered,left=0,top=0,width=810,height=620,scrollbars=yes,menubar=no,resizable=yes,toolbar=no');
#     if (win3 && win3.open && !win3.closed)win3.window.focus();
#     }
#     function television(tournamentid, tgameid, gamelinkid, gameid, teamid1, teamid2, drawid)
#     {
#     win3 = window.open('https://www.curlingzone.com/forums/scores/television.php?tournamentid='+tournamentid+'&tournamentgameid='+tgameid+'&gamelinkid='+gamelinkid+'&gameid='+gameid+'&teamid1='+teamid1+'&teamid2='+teamid2+'&drawid='+drawid, 'GameScore', 'centered,left=0,top=0,width=810,height=620,scrollbars=yes,menubar=no,resizable=yes,toolbar=no');
#     if (win3 && win3.open && !win3.closed)win3.window.focus();
#     }
#     </script><script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-19251053-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'https://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# </script><script>(function() {
#   var _fbq = window._fbq || (window._fbq = []);
#   if (!_fbq.loaded) {
#     var fbds = document.createElement('script');
#     fbds.async = true;
#     fbds.src = '//connect.facebook.net/en_US/fbds.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(fbds, s);
#     _fbq.loaded = true;
#   }
#   _fbq.push(['addPixelId', '571900446262990']);
# })();
# window._fbq = window._fbq || [];
# window._fbq.push(['track', 'PixelInitialized', {}]);
# </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=571900446262990&amp;ev=NoScript" style="display:none" width="1"/></noscript><script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/2340375/Header_728x90', [728, 90], 'div-gpt-ad-1511895740204-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/2340375/Left_Top_300x100', [[300, 50], [300, 100], [300, 75]], 'div-gpt-ad-1511898449749-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
#   });
# </script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/2340375/Right_Middle_250x150', [[250, 250], [250, 150], [250, 100]], 'div-gpt-ad-1512220692871-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/2340375/Right_BigBox_250x250', [250, 250], 'div-gpt-ad-1512221054605-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# </link></meta></meta></head>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/2340375/Left_Middle_250x250', [250, 250], 'div-gpt-ad-1512221224310-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <!-- Fly Or Die Curling -->
# <script>
# FOD_LANG='en';
# FOD_SITE='curlingzone';
# FOD_PORTAL='partner';
# </script>
# <script>document.write('<script src="'+'https://www.flyordie.com'+'/free-online-games.jhtm"><'+'/script>');</script>
# <body class="home blog body-class">
# <!-- Start Top Content -->
# <div id="header">
# <div class="top-line"></div>
# <!-- START Headline and Date -->
# <div class="container">
# <div class="row-fluid">
# <div class="span12">
# <div class="top-info">
# <div class="row-fluid">
# <!-- start Date section -->
# <div class="span4 min-height entry-time">
# <div class="floatLeft">Welcome <b>Guest</b>!
#   <a href="https://www.curlingzone.com/register.php?action=RegGUp#1" title="Sign Up">Register</a> | <a href="https://www.curlingzone.com/login.php?action=RegGUp#1" title="Sign Up">Login</a> </div>
# </div> <!-- /span6 min-height -->
# </div> <!-- /row-fluid -->
# </div> <!-- /top-info -->
# </div> <!-- /span12 -->
# </div> <!-- /row-fluid -->
# </div> <!-- /container -->
# <!-- END headline and date -->
# <!-- START Logo and Banner -->
# <div class="container">
# <div class="row-fluid entry-header">
# <!-- start Logo section -->
# <div class="span4 entry-logo">
# <div id="logo">
# <a href="index.php"><img alt="CurlingZone" src="https://www.curlingzone.com/talk/wp-content/uploads/2016/05/logo_nav.png"/></a>
# </div> <!-- #logo -->
# </div><!-- /span4 -->
# <!-- start Banner section -->
# <div class="span8 entry-banner">
# <div id="banner"><!-- /2340375/Header_728x90 -->
# <div id="div-gpt-ad-1511895740204-0" style="height:90px; width:728px;">
# <script>
# 	googletag.cmd.push(function() { googletag.display('div-gpt-ad-1511895740204-0'); });
# 	</script>
# </div></div><!-- /banner -->
# </div><!-- /span8 -->
# </div><!-- /row-fluid -->
# <!-- END Logo and Banner -->
# <!-- START Menu -->
# <div id="mainmenu-block-bg">
# <div class="container">
# <div class="row-fluid">
# <div class="span12 min-height">
# <div class="navigation">
# <div id="menu">
# <div class="menu-main-container">
# <ul class="sf-menu" id="menu-main">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-574" id="menu-item-574"><a href="https://www.curlingzone.com/">Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-575" id="menu-item-575"><a href="https://www.curlingzone.com/rankings.php#1">Rankings</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-576" id="menu-item-576"><a href="https://www.curlingzone.com/schedule.php?eventyear=2021&amp;et=81#1">Events</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-577" id="menu-item-577"><a href="https://www.curlingzone.com/teams.php#1">Teams</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-578" id="menu-item-578"><a href="https://www.curlingzone.com/scoreboard.php#1">Scores</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-579" id="menu-item-579"><a href="https://www.curlingzone.com/fantasy/index.php#1">Fantasy</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-forum menu-item-580" id="menu-item-580"><a href="https://www.curlingzone.com/analytics.php#1">Analytics</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-581" id="menu-item-581"><a href="https://www.curlingzone.com/news.php?s=#1">News</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-582" id="menu-item-582"><a href="https://www.curlingzone.com/blogs.php#1">Blogs</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-583" id="menu-item-583"><a href="https://www.curlingzone.com/forumdisplay.php?forumid=1&amp;s=#1">Forums</a></li>
# <li class="menu-item menu-item-type-post_type_archive menu-item-object-forum menu-item-584" id="menu-item-584"><a href="https://iss4u.de/?lang=en">Ice Facilities</a></li>
# </ul>
# </div>
# </div> <!-- /menu --> </div> <!-- /navigation -->
# </div> <!-- /span12 -->
# </div><!-- /row-fluid -->
# </div> <!-- container -->
# </div> <!-- mainmenu-block-bg -->
# <!-- END Menu -->
# </div><!-- /container -->
# <!-- END TOP BLOCK -->
# </div> <!-- #header --><div class="margin-10t"></div>
# <!-- START CONTENT ENTRY -->
# <div class="container" id="content">
# <!-- ( CONTENT + LEFT ) + RIGHT -->
# <div class="row-fluid">
# <div class="span3">
# <div class="widget widget_text clearfix">
# <div class="textwidget"><!-- /2340375/Left_Top_300x100 -->
# <div id="div-gpt-ad-1511898449749-0">
# <script>
# 	googletag.cmd.push(function() { googletag.display('div-gpt-ad-1511898449749-0'); });
# 	</script>
# </div></div>
# </div><!-- .widget -->
# <!-- .widget -->
# <div class="widget widget_categories clearfix">
# <div class="widget-header"><h3 class="entry-title-widget">Content Menu</h3></div>
# <div class="bottom-line"></div>
# <ul>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=week&amp;oomid=81&amp;eventyear=2021#1">Rankings - Men</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=teams&amp;oomid=81&amp;eventyear=2021#1">Teams - Men</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=events&amp;oomid=81&amp;eventyear=2021#1">Events - Men</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=champions&amp;oomid=81&amp;eventyear=2021#1">Champions - Men</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=week&amp;oomid=82&amp;eventyear=2021#1">Rankings - Women</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=teams&amp;oomid=82&amp;eventyear=2021#1">Teams - Women</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=events&amp;oomid=82&amp;eventyear=2021#1">Events - Women</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=champions&amp;oomid=82&amp;eventyear=2021#1">Champions - Women</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=week&amp;oomid=85&amp;eventyear=2021#1">Rankings - Mixed Doubles</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=week&amp;oomid=85&amp;eventyear=2021&amp;playerpos=4#1">Rankings - Doubles: Female</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=week&amp;oomid=85&amp;eventyear=2021&amp;playerpos=3#1">Rankings - Doubles: Male</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=teams&amp;oomid=85&amp;eventyear=2021#1">Teams - Mixed Doubles</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=events&amp;oomid=85&amp;eventyear=2021#1">Events - Mixed Doubles</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=champions&amp;oomid=85&amp;eventyear=2021#1">Champions - Mixed Doubles</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=calculations&amp;oomid=81&amp;eventyear=2021#1">Calculations</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=about&amp;oomid=81&amp;eventyear=2021#1">About</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=week&amp;oomid=81&amp;eventyear=2020#1">Last Year</a></li>
# <li class="cat-item cat-item-1"><a href="rankings.php?task=week&amp;oomid=81&amp;eventyear=2018#1">Current Year</a></li></ul>
# </div><!-- .widget --> <div class="widget widget_text clearfix">
# <div class="textwidget"><div class="rightcontent">
# <script type="text/javascript"><!--
#     google_ad_client = "pub-9285914840898296";
#     /* 250x250, CZ: side box */
#     google_ad_slot = "3893048829";
#     google_ad_width = 250;
#     google_ad_height = 250;
#     //-->
#     </script>
# <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# </div></div>
# </div>
# <script type="text/javascript">
# function SwitchMenuTop(obj, obj2, obj3){
# 	if(document.getElementById){
# 	var el = document.getElementById(obj);
# 	var dy = document.getElementById(obj3);
# 	var ar = document.getElementById(obj2).getElementsByTagName("DIV");
# 		if(el.style.display == "none"){
# 			for (var i=0; i<ar.length; i++){
# 				ar[i].style.display = "none";
# 			}
# 			el.style.display = "block";
# 		}
# 		if(dy.style.display == "none"){
# 			for (var i=0; i<dy.length; i++){
# 				ar[i].style.display = "none";
# 			}
# 			dy.style.display = "block";
# 		}
#
# 	}
# }
# function SwitchMenu(obj, obj2){
# 	if(document.getElementById){
# 	var el = document.getElementById(obj);
# 	var ar = document.getElementById(obj2).getElementsByTagName("DIV");
# 		if(el.style.display == "none"){
# 			for (var i=0; i<ar.length; i++){
# 				ar[i].style.display = "none";
# 			}
# 			el.style.display = "block";
# 		}
#
# 	}
# }
# function ChangeClass(menu, newClass) {
# 	 if (document.getElementById) {
# 	 	document.getElementById(menu).className = newClass;
# 	 }
# }
# document.onselectstart = new Function("return false");
# </script> <div class="mobilehide" id="variable">
# <div class="widget widget_archive clearfix">
# <div class="widget-header"><h3 class="entry-title-widget">Curling Scores</h3></div>
# <div class="bottom-line"></div>
# <table border="1" cellpadding="2" cellspacing="0" width="100%">
# <tr>
# <td class="scorea" id="scoreboard_front">
# <!--start-->
# <div id="oom" style="display:block;"><table bgcolor="#0a193e" cellpadding="5" cellspacing="1" class="rightcontent" id="scoreboard" width="100%">
# <tr>
# <td align="right" class="scorea" colspan="3" id="scoreboard_front"><b><div id="oom_event1" style="display:block;"><table width="100%"><tr><td bgcolor="#dddddd"><a href="event.php?view=Main&amp;eventid=6855#1"><b>M: Tim Hortons Brier</b></a><br/>Calgary, AB<br/><a href="event.php?view=Teams&amp;eventid=6855#1">Teams</a> | <a href="event.php?view=Scores&amp;eventid=6855#1">Scores</a> | <a href="event.php?view=Round-Robin&amp;eventid=6855#1">Standings</a> | <a href="event.php?view=Playoffs&amp;eventid=6855#1">Playoffs</a></td></tr></table><table width="100%"><tr bgcolor="white">
# <td colspan="4"><a name="draw25">Draw: CF</a> -- Sun, Mar 14 -- 6:30pm MT</td>
# </tr><tr bgcolor="white">
# <td colspan="4"><b><tr bgcolor="#e3f3ff">
# <td height="15" width="25"><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283108#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/236_flag.gif"/></a></td>
# <td><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283108#1">Wildcard (Koe)</a></td>
# <td align="right">2 </td>
# <td><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283108#1">Final</a></td>
# </tr>
# <tr bgcolor="#e3f3ff">
# <td height="15" width="25"><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283108#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/236_flag.gif"/></a></td>
# <td><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283108#1">Alberta (Bottcher)</a></td>
# <td align="right">4 </td>
# <td>(9)</td></tr></b></td></tr></table></div></b></td></tr></table></div></td></tr></table></div></div></div></div></div></body></html>
# <div id="oom_event2" style="display:block;"><table width="100%"><tr><td bgcolor="#dddddd"><a href="event.php?view=Main&amp;eventid=6856#1"><b>: Northwest Territories Mixed Championship</b></a><br/>Inuvik, NT<br/><a href="event.php?view=Teams&amp;eventid=6856#1">Teams</a> | <a href="event.php?view=Scores&amp;eventid=6856#1">Scores</a> | <a href="event.php?view=Round-Robin&amp;eventid=6856#1">Standings</a> | <a href="event.php?view=Playoffs&amp;eventid=6856#1">Playoffs</a></td></tr></table><table width="100%"><tr bgcolor="white">
# <td colspan="4"><a name="draw4">Draw: CF</a> -- Sat, Mar 6 -- 11:00am ET</td>
# </tr><tr bgcolor="white">
# <td colspan="4"><b><tr bgcolor="#e3f3ff">
# <td height="15" width="25"><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283084#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/265_flag.gif"/></a></td>
# <td><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283084#1">Robertson</a></td>
# <td align="right">3 </td>
# <td><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283084#1">Final</a></td>
# </tr>
# <tr bgcolor="#e3f3ff">
# <td height="15" width="25"><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283084#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/265_flag.gif"/></a></td>
# <td><a href="https://www.curlingzone.com/game.php?1=1&amp;showgameid=283084#1">Koe</a></td>
# <td align="right">10 </td>
# <td>(7)</td></tr></b></td></tr></table></div>
# <table width="100%"></table>
#
#
# <!--end-->
#
#
# <tr>
# <td align="center" colspan="3"><a href="https://www.curlingzone.com/scoreboard.php?s=5678d16e337b8adacc76419b3eb6dc10#1">Full Scoreboard</a>  <font color="white">|</font>  <a href="https://www.curlingzone.com/fantasy/index.php?s=5678d16e337b8adacc76419b3eb6dc10#1">Play Fantasy Pick'em!</a>  <font color="white"></font></td>
# </tr>
#  <!-- .widget -->
# <div class="widget widget_text clearfix mobilehide">
# <div class="textwidget"><div class="rightcontent">
# <script type="text/javascript"><!--
#     google_ad_client = "pub-9285914840898296";
#     /* 250x250, CZ: side box */
#     google_ad_slot = "3893048829";
#     google_ad_width = 250;
#     google_ad_height = 250;
#     //-->
#     </script>
# <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# </div></div>
# </div><!-- .widget -->
#
# <!-- span3 --> <div class="span9">
# <div class="row-fluid">
# <div class="span12">
# <a name="curling">
# <a name="1"><table width="100%">
# <tr>
# <td width="125"><img src="https://www.curlingzone.com/images/wcf125.png"/></td>
# <td width="5"> </td>
# <td><h3 class="entry-title-widget">2021 World Team Rankings: MEN</h3>
# <div class="bottom-line"></div>
# <div id="menu">
# <div class="menu-main-container">
# <ul class="sf-menu" id="menu-main">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item
# <td data-th="Team"><a href="team.php?teamid=147946&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1">Colton Flasch</a></td><td data-th="Location">Saskatchewan</td><td data-th="YTD">0.000</td><td data-th="Total">196.835</td>
# </tr><tr bgcolor="#EEEEEE">
# <td data-th="Rank">19.</td>
# <td data-th="Team" height="15" width="25"><a href="team.php?teamid=148215&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/5_flag.gif"/></a></td>
# <td data-th="Team"><a href="team.php?teamid=148215&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1">Glenn Howard</a></td><td data-th="Location">Ontario</td><td data-th="YTD">0.000</td><td data-th="Total">184.546</td>
# </tr><tr>
# <td data-th="Rank">20.</td>
# <td data-th="Team" height="15" width="25"><a href="team.php?teamid=147787&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/4_flag.gif"/></a></td>
# <td data-th="Team"><a href="team.php?teamid=147787&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1">John Shuster</a></td><td data-th="Location">Minnesota</td><td data-th="YTD">0.000</td><td data-th="Total">181.864</td>
# </tr><tr bgcolor="#EEEEEE">
# <td data-th="Rank">21.</td>
# <td data-th="Team" height="15" width="25"><a href="team.php?teamid=149261&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/301_flag.gif"/></a></td>
# <td data-th="Team"><a href="team.php?teamid=149261&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1">Chang-Min Kim</a></td><td data-th="Location">Korea</td><td data-th="YTD">0.000</td><td data-th="Total">179.167</td>
# </tr><tr>
# <td data-th="Rank">22.</td>
# <td data-th="Team" height="15" width="25"><a href="team.php?teamid=149264&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/5_flag.gif"/></a></td>
# <td data-th="Team"><a href="team.php?teamid=149264&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1">Tanner Horgan</a></td><td data-th="Location">Manitoba</td><td data-th="YTD">0.000</td><td data-th="Total">176.554</td>
# </tr><tr bgcolor="#EEEEEE">
# <td data-th="Rank">23.</td>
# <td data-th="Team" height="15" width="25"><a href="team.php?teamid=148118&amp;profileid=&amp;view=OOM&amp;OOMweek=29#1"><img height="15" src="https://www.curlingzone.com/forums/images/flag/5_flag.gif"/></a></td>
# ...
# <span class="post-date-widget">February 8, 2018</span><!-- post-date-widget -->
# <div class="clear"></div>
# </div> <!-- /entry-info-post -->
# </li>
# </ul>
# </div><!-- span6 -->
# </div><!-- row-fluid -->
# </div><!-- .widget --><div class="widget ct_recentposts_widget clearfix">
# <div class="widget-header"><div class="row-fluid"><div class="span8 min-height"><h3 class="entry-title-widget">Curling Photos</h3></div><div class="span4 min-height"><div class="badge-widget" style="background-color:#50caff ">Recent</div><!-- /badge-widget --></div><!-- /span4 --></div> <!-- /row-fluid --></div><div class="bottom-line"></div>
# <div class="bottom-line" style="border-top-color:#575e60;"></div>
# <!-- Start List -->
# <!-- first post -->
# <div class="first-post">
# <!-- start post thumb -->
# <div class="blog-thumb">
# <a href="photos.php?galleryid=378#1"><img alt="" src="https://www.curlingzone.com/forums/images/photos/curling7516.jpg"/></a>
# </div> <!-- /entry-thumb -->
# <div class="clear"></div>
# <!-- start title -->
# <div class="post-title">
# <h3 class="entry-title">
# <a href="photos.php?galleryid=378#1" title="Permalink to "></a>
# </h3>
# </div> <!-- post-title -->
# <!-- Post Date -->
# <span class="post-date-widget"></span><!-- post-date-widget -->
# <div class="margin-5b"></div>
# <p></p>
# </div> <!-- /first-post -->
# <ul class="recentposts-widget">
# <li class="clearfix">
# <div class="widget-thumb">
# <a href="photos.php?galleryid=377#1#1" title="Permalink to "><img alt="" src="https://www.curlingzone.com/forums/images/photos/curling7515.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="photos.php?galleryid=377#1#1" title=""></a></div><!-- post-title -->
# <span class="post-date-widget"></span><!-- post-date-widget -->
# <div class="clear"></div>
# </div> <!-- /entry-info-post -->
# </li><li class="clearfix">
# <div class="widget-thumb">
# <a href="photos.php?galleryid=376#1#1" title="Permalink to "><img alt="" src="https://www.curlingzone.com/forums/images/photos/curling7514.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="photos.php?galleryid=376#1#1" title=""></a></div><!-- post-title -->
# <span class="post-date-widget"></span><!-- post-date-widget -->
# <div class="clear"></div>
# </div> <!-- /entry-info-post -->
# </li><li class="clearfix">
# <div class="widget-thumb">
# <a href="photos.php?galleryid=370#1#1" title="Permalink to Test post"><img alt="Test post" src="https://www.curlingzone.com/forums/images/photos/curling7055.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="photos.php?galleryid=370#1#1" title="Test post">Test post</a></div><!-- post-title -->
# <span class="post-date-widget"></span><!-- post-date-widget -->
# <div class="clear"></div>
# </div> <!-- /entry-info-post -->
# </li><li class="clearfix">
# <div class="widget-thumb">
# <a href="photos.php?galleryid=369#1#1" title="Permalink to "><img alt="" src="https://www.curlingzone.com/forums/images/photos/curling7054.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="photos.php?galleryid=369#1#1" title=""></a></div><!-- post-title -->
# <span class="post-date-widget"></span><!-- post-date-widget -->
# <div class="clear"></div>
# </div> <!-- /entry-info-post -->
# </li>
# </ul> <!-- end list ( recentposts-widget ) -->
# </div><!-- .widget --><div class="widget ct_recentposts_widget">
# <div class="widget-header"><h3 class="entry-title-widget">Curling Blogs</h3></div>
# <div class="bottom-line"></div>
# <div class="bottom-line" style="border-top-color:#575e60;"></div>
# <ul class="recentposts-widget">
# <li class="clearfix">
# <div class="widget-thumb"><a href="http://curlwithmath.blogspot.com/2021/02/episode-74-rae-kellsdonna-boyle.html" target="_blank" title="Permalink to CURL WITH MATH"><img alt="CURL WITH MATH: ..." src="https://www.curlingzone.com/images/blogs/rss_math.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="http://curlwithmath.blogspot.com/2021/02/episode-74-rae-kellsdonna-boyle.html" target="_blank" title="CURL WITH MATH">CURL WITH MATH: ...</a></div><!-- post-title -->
# <div class="recentcomments">Rae Kells was prepared for the challenge.;nbsp; Her experience as a probations officer provided ideal training for work as a curling official. ;nbsp;Her steady... <span align="right">(<a href="http://curlwithmath.blogspot.com/2021/02/episode-74-rae-kellsdonna-boyle.html" target="_blank" title="CURL WITH MATH">read more</a>)</span></div>
# <div class="clear"></div>
# </div> <!-- /entry-info-post --></li>
# <li class="clearfix">
# <div class="widget-thumb"><a href="https://www.spreaker.com/user/10595454/extraend-episode20-053020-final" target="_blank" title="Permalink to EXTRA EXTRA END PODCAST"><img alt="EXTRA EXTRA END PODCAST: E20: Two-time U.S. Olympian Jessica..." src="https://www.curlingzone.com/images/blogs/rss_extraextraend.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="https://www.spreaker.com/user/10595454/extraend-episode20-053020-final" target="_blank" title="EXTRA EXTRA END PODCAST">EXTRA EXTRA END PODCAST: E20: Two-time U.S. Olympian Jessica...</a></div><!-- post-title -->
# <div class="recentcomments">A quick break for the Memorial Day holiday and we're back with our guest and new USA Curling Womenâs National Team &amp; Juniors Director Jessica Schultz.... <span align="right">(<a href="https://www.spreaker.com/user/10595454/extraend-episode20-053020-final" target="_blank" title="EXTRA EXTRA END PODCAST">read more</a>)</span></div>
# <div class="clear"></div>
# </div> <!-- /entry-info-post --></li>
# <li class="clearfix">
# <div class="widget-thumb"><a href="http://truenorthbill.blogspot.com/2020/03/canadas-greatest-asset-may-also-be-its.html" target="_blank" title="Permalink to COACH BILL"><img alt="COACH BILL: Canadaâs Greatest Asset May..." src="https://www.curlingzone.com/images/blogs/rss_coachbill.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="http://truenorthbill.blogspot.com/2020/03/canadas-greatest-asset-may-also-be-its.html" target="_blank" title="COACH BILL">COACH BILL: Canadaâs Greatest Asset May...</a></div><!-- post-title -->
# <div class="recentcomments">The curling season worldwide has come to a screeching halt along with the seasons of every other sport on this third rock from the sun. Who would have suspected... <span align="right">(<a href="http://truenorthbill.blogspot.com/2020/03/canadas-greatest-asset-may-also-be-its.html" target="_blank" title="COACH BILL">read more</a>)</span></div>
# <div class="clear"></div>
# </div> <!-- /entry-info-post --></li>
# <li class="clearfix">
# <div class="widget-thumb"><a href="https://inthehousecurling.blogspot.com/2020/03/doing-jello-shots-with-my-kids-and-team.html" target="_blank" title="Permalink to MIKE THE CURLING GUY"><img alt="MIKE THE CURLING GUY: Doing Jello Shots with my Kids..." src="https://www.curlingzone.com/images/blogs/rss_inthehouse.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="https://inthehousecurling.blogspot.com/2020/03/doing-jello-shots-with-my-kids-and-team.html" target="_blank" title="MIKE THE CURLING GUY">MIKE THE CURLING GUY: Doing Jello Shots with my Kids...</a></div><!-- post-title -->
# <div class="recentcomments">I am in week 3 of isolation/quarantine/home schooling and getting a little squirrel-y. Personal hygiene has become optional. The kids have watched the entire... <span align="right">(<a href="https://inthehousecurling.blogspot.com/2020/03/doing-jello-shots-with-my-kids-and-team.html" target="_blank" title="MIKE THE CURLING GUY">read more</a>)</span></div>
# <div class="clear"></div>
# </div> <!-- /entry-info-post --></li>
# <li class="clearfix">
# <div class="widget-thumb"><a href="http://bit.ly/33qIU2Y" target="_blank" title="Permalink to WORLD CURLING REPORT"><img alt="WORLD CURLING REPORT: November 27th, 2019" src="https://www.curlingzone.com/images/blogs/rss_fth.jpg"/></a>
# </div><!-- widget-post-small-thumb -->
# <!-- has_post_thumbnail -->
# <!-- Start ENTRY INFO POST -->
# <div class="entry-info-post">
# <!-- Post Title -->
# <div class="post-title"><a href="http://bit.ly/33qIU2Y" target="_blank" title="WORLD CURLING REPORT">WORLD CURLING REPORT: November 27th, 2019</a></div><!-- post-title -->
# <div class="recentcomments">On today's World Curling Report...we recap Day 1 of the 2019 Canada Cup.   <span align="right">(<a href="http://bit.ly/33qIU2Y" target="_blank" title="WORLD CURLING REPORT">read more</a>)</span></div>
# <div class="clear"></div>
# </div> <!-- /entry-info-post --></li></ul>
# </div><!-- .widget --></div> <!-- /span6 -->
# <div class="span4">
# <div class="widget ct_fblikebox_widget clearfix">
# <div class="widget-header"><h3 class="entry-title-widget">Facebook Feed</h3></div><div class="bottom-line"></div>
# <div class="bottom-line" style="border-top-color:#575e60;"></div>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# 	  var js, fjs = d.getElementsByTagName(s)[0];
# 	  if (d.getElementById(id)) return;
# 	  js = d.createElement(s); js.id = id;
# 	  js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
# 	  fjs.parentNode.insertBefore(js, fjs);
# 	}(document, 'script', 'facebook-jssdk'));</script>
# <div class="facebook-box">
# <div class="fb-like-box" data-border-color="#fff" data-header="true" data-href="http://facebook.com/CurlingZone" data-show-faces="true" data-stream="false"></div>
# <div class="clear"></div>
# </div><!-- facebook-box -->
# </div><!-- .widget -->
# <div class="widget ct_fblikebox_widget clearfix">
# <div class="widget-header"><h3 class="entry-title-widget">Twitter Feed</h3></div><div class="bottom-line"></div>
# <div class="bottom-line" style="border-top-color:#575e60;"></div>
# <div class="widget widget_text clearfix">
# <div class="textwidget"><a class="twitter-timeline" data-height="650" href="http://www.twitter.com/CurlingZone">Tweets by CurlingZone</a> <script async="" charset="utf-8" src="//platform.twitter.com/widgets.js"></script></div>
# </div><!-- .widget -->
# </div><!-- .widget -->
# </div> <!-- /span4 -->
# </div> <!-- /row-fluid --> <!-- span9 -->
# <!-- row-fluid -->
# <!-- ( CONTENT + LEFT ) + RIGHT -->
#  <!-- #content -->
# <!-- END CONTENT ENTRY -->
# <a class="to-top" href="#" title="To top">To top ↑</a>
# <div id="footer">
# <div class="container footer">
# <div class="row-fluid">
# <div class="span9">
# <div class="menu-main-container">
# <ul class="footer-menu" id="menu-main-1">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-574"><a href="https://www.curlingzone.com/">Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-575"><a href="https://www.curlingzone.com/rankings.php#1">Rankings</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-575"><a href="https://www.curlingzone.com/schedule.php?eventyear=2021&amp;et=81#1">Events</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-576"><a href="https://www.curlingzone.com/statistics.php#1">Teams</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-576"><a href="https://www.curlingzone.com/scoreboard.php#1">Scores</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-579"><a href="https://www.curlingzone.com/fantasy/index.php#1">Fantasy</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-forum menu-item-591"><a href="https://www.curlingzone.com/analytics.php#1">Analytics</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-577"><a href="https://www.curlingzone.com/news.php?s=#1">News</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-575"><a href="https://www.curlingzone.com/blogs.php#1">Blogs</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-forum menu-item-591"><a href="https://www.curlingzone.com/analytics.php#1">Analytics</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-574"><a href="https://www.curlingzone.com/forumdisplay.php?forumid=1&amp;s=">Forums</a></li>
# <li class="menu-item menu-item-type-post_type_archive menu-item-object-forum menu-item-592"><a href="https://iss4u.de/?lang=en">Ice Facilities</a></li>
# </ul>
# </div> </div> <!-- /span9 -->
# <div class="span3">
# <form action="https://www.curlingzone.com/talk/" class="searchform" method="get">
# <input class="field s" name="s" placeholder="search this site..." type="text"/>
# </form>
# </div> <!-- /span3 -->
# </div> <!-- /row-fluid -->
# </div>
# <div class="footer-bottom">
# <div class="container">
# <div class="row-fluid">
# <div class="span6 copyright">2021 © Copyright. Powered by <a href="https://www.curlingzone.com/">CurlingZone</a></div>
# <div class="span6 add-info"><a href="https://www.curlingzone.com/terms.php">Terms</a> | <a href="https://www.curlingzone.com/privacy.php">Privacy Policy</a><br><a href="https://www.curlingzone.com/CurlingZoneRateCard.pdf">Advertise With CurlingZone</a></br></div>
# </div>
# </div>
# </div>
# </div><!-- #footer -->
# <script type="text/javascript">
# /* <![CDATA[ */
# jQuery.noConflict()(function($){
# $(document).ready(function(){
# var sticky_navigation_offset_top = $('#mainmenu-block-bg').offset().top;
# var sticky_navigation = function(){
# var scroll_top = $(window).scrollTop(); // our current vertical position from the top
# var menuheight = $('#mainmenu-block-bg').height();
#
# if (scroll_top > sticky_navigation_offset_top) {
# $('#mainmenu-block-bg').css({ 'position': 'fixed', 'top':0, 'left':0, 'z-index':30, 'width': '100%' });
# $('body').css({ 'padding-top': menuheight });
# } else {
# $('#mainmenu-block-bg').css({ 'top':0, 'position': 'relative','padding-top':0, 'width': 'auto' });
# $('body').css({ 'padding-top': 0 });
# }
# };
#
# // run our function on load
# sticky_navigation();
#
# // and run it again every time you scroll
# $(window).scroll(function() {
# sticky_navigation();
# });
# });
# });
# /* ]]> */
# </script>
# <script src="https://www.curlingzone.com/talk/wp-content/plugins/bbpress/templates/default/js/editor.js?ver=2.5.9-6017" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/js/jquery.ticker.js" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/js/jquery.prettyphoto.js" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/js/bootstrap.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var customjs = {"headline":"Headline"};
# /* ]]> */
# </script>
# <script src="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/js/custom.js" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-includes/js/wp-embed.min.js?ver=4.5.2" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/js/jquery.flexslider-min.js" type="text/javascript"></script>
# <script src="https://www.curlingzone.com/talk/wp-content/themes/wp-volcano/js/spectragram.min.js" type="text/javascript"></script>

# %%
def find_all_teams(soup):
    return find_all(soup=soup,name='td',attrs={'data-th':'Team'})
def find_all_ranks(soup):
    return find_all(soup=soup,name='td',attrs={'data-th':'Rank'})
def find_all_totals(soup):
    return find_all(soup=soup,name='td',attrs={'data-th':'Total'})
def find_all_ytds(soup):
    return find_all(soup=soup,name='td',attrs={'data-th':'YTD'})

# %%
find_all_ranks(soup)[0:5]
# Out:
# [<td data-th="Rank">1.</td>,
#  <td data-th="Rank">2.</td>,
#  <td data-th="Rank">3.</td>,
#  <td data-th="Rank">4.</td>,
#  <td data-th="Rank">5.</td>]

# %%
find_all_totals(soup)[0:5]
# Out:
# [<td data-th="Total">483.766</td>,
#  <td data-th="Total">445.311</td>,
#  <td data-th="Total">395.747</td>,
#  <td data-th="Total">347.977</td>,
#  <td data-th="Total">343.005</td>]

# %%
find_all_ytds(soup)[0:5]
# Out:
# [<td data-th="YTD">0.000</td>,
#  <td data-th="YTD">0.000</td>,
#  <td data-th="YTD">0.000</td>,
#  <td data-th="YTD">0.000</td>,
#  <td data-th="YTD">0.000</td>]

# %%
def get_team_ranks(tags):
    return {
        
         "Rank":[tag.string.strip() for tag in tags]
        ,"TeamElementHash":[tag.parent.__hash__() for tag in tags]
        
        
    }

def get_team_ranks_from_soup(soup):
    tags = find_all_ranks(soup=soup)
    return get_team_ranks(tags=tags)

def get_team_ranks_frame_from_soup(soup):
    return get_frame(get_team_ranks_from_soup(soup=soup))

def get_team_totals(tags):
    return{
        
         "PointTotal":[tag.string.strip() for tag in tags]
        ,"TeamElementHash":[tag.parent.__hash__() for tag in tags]
        
    }

def get_team_totals_from_soup(soup):
    tags = find_all_totals(soup=soup)
    return get_team_totals(tags=tags)

def get_team_totals_frame_from_soup(soup):
    return get_frame(get_team_totals_from_soup(soup=soup))
    
def get_team_ytds(tags):
    return {
        
         "YTDPoints":[tag.string.strip() for tag in tags]
        ,"TeamElementHash":[tag.parent.__hash__() for tag in tags]
        
        
    }
def get_team_ytds_from_soup(soup):
    tags = find_all_ytds(soup=soup)
    return get_team_ytds(tags=tags)

def get_team_ytds_frame_from_soup(soup):
    return get_frame(get_team_ytds_from_soup(soup=soup))

def get_team_links(tags):
    return {
        
         "TeamLink":[tag.a['href'] for tag in tags if tag.a.string]
        ,"Name":[tag.a.string for tag in tags if tag.a.string]
        ,"TeamElementHash":[tag.parent.__hash__() for tag in tags if tag.a.string]
        
    }

def get_team_links_from_soup(soup):
    tags = find_all_teams(soup=soup)
    return get_team_links(tags=tags)

def get_team_links_frame_from_soup(soup):
    return get_frame(get_team_links_from_soup(soup=soup))

def get_frame(data,index=True):
    
    df = pd.DataFrame(data=data)
    
    if index:
        df=df.set_index(keys='TeamElementHash',drop=True)
        
    return df 

def scrape_all_rankings(url,year=None):
    soup = get_soup(url=url)
    
    team_links = get_team_links_frame_from_soup(soup)
    team_ytds = get_team_ytds_frame_from_soup(soup)
    team_totals = get_team_totals_frame_from_soup(soup)
    team_ranks = get_team_ranks_frame_from_soup(soup)
    
    df = pd.concat([team_links,team_ytds,team_totals,team_ranks],axis=1)
    
    df['Year'] = year

    
    return df

# %%
scrape_all_rankings(url="https://www.curlingzone.com/rankings.php?task=week&oomid=81&eventyear=2020#1")
# Out:
#                                                           TeamLink  \
# TeamElementHash
# -1143695436      team.php?teamid=134539&profileid=&view=OOM&OOM...
# -170019375       team.php?teamid=134149&profileid=&view=OOM&OOM...
# -2033196918      team.php?teamid=134658&profileid=&view=OOM&OOM...
# -996801756       team.php?teamid=133900&profileid=&view=OOM&OOM...
# -1837416361      team.php?teamid=134492&profileid=&view=OOM&OOM...
#  266977469       team.php?teamid=134333&profileid=&view=OOM&OOM...
# -1294030979      team.php?teamid=134858&profileid=&view=OOM&OOM...
# -1024578674      team.php?teamid=134525&profileid=&view=OOM&OOM...
# -760583075       team.php?teamid=134345&profileid=&view=OOM&OOM...
# -517507247       team.php?teamid=134410&profileid=&view=OOM&OOM...
#  267656440       team.php?teamid=134494&profileid=&view=OOM&OOM...
# -518915412       team.php?teamid=134147&profileid=&view=OOM&OOM...
# -1945326182      team.php?teamid=134421&profileid=&view=OOM&OOM...
# -845816567       team.php?teamid=134276&profileid=&view=OOM&OOM...
# -1455558467      team.php?teamid=134427&profileid=&view=OOM&OOM...
#  286553721       team.php?teamid=134119&profileid=&view=OOM&OOM...
#  1642481513      team.php?teamid=134404&profileid=&view=OOM&OOM...
# -638564061       team.php?teamid=134335&profileid=&view=OOM&OOM...
#  345756968       team.php?teamid=134391&profileid=&view=OOM&OOM...
# -457258533       team.php?teamid=134260&profileid=&view=OOM&OOM...
#  216854445       team.php?teamid=134230&profileid=&view=OOM&OOM...
#  1763759746      team.php?teamid=134320&profileid=&view=OOM&OOM...
