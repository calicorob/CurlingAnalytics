# %%
# library imports

# file IO, processing
import pandas as pd

# db con
from config import get_engine

# analysis
from analysis import get_win_pcts,get_scores

# %%
# db con params
database='dnorm'

# engine
engine = get_engine(database=database)

# %%
# get data

df = get_scores(classification='men 8 end')

# %%
# display

df.head()
# Out:
#    PivotedScoreID  GameID  EndNum  EndResult  Hammer  Score  TeamID  EventID  \
# 0          751418   47846       1         -1       1      0  121243     5329
# 1          751420   47846       2          3       1      0  121243     5329
# 2          751422   47846       3         -1       0      3  121243     5329
# 3          751424   47846       4          0       1      3  121243     5329
# 4          751426   47846       5          0       1      3  121243     5329
#
#                   EventName  Year  EndMonth  EventDayEnd     Season  \
# 0  Red Deer Curling Classic  2018        11           19  2018-2019
# 1  Red Deer Curling Classic  2018        11           19  2018-2019
# 2  Red Deer Curling Classic  2018        11           19  2018-2019
# 3  Red Deer Curling Classic  2018        11           19  2018-2019
# 4  Red Deer Curling Classic  2018        11           19  2018-2019
#
#    FinalScore         Team  EndSituation  OpponentTeamID  OpponentFinalScore  \
# ...

# %%
cols = ['EndNum','EndSituation','Hammer']

# %%
df.loc[df.Team=='Brendan Bottcher'].drop_duplicates(subset=['GameID']).FinalScore.mean()
# Out:
# 5.955357142857143

# %%
df.loc[df.Team=='Brendan Bottcher'].drop_duplicates(subset=['GameID']).OpponentFinalScore.mean()
# Out:
# 3.8125

# %%
df.loc[df.Team=='Niklas Edin'].drop_duplicates(subset=['GameID']).FinalScore.mean()
# Out:
# 5.628318584070796

# %%
df.loc[df.Team=='Niklas Edin'].drop_duplicates(subset=['GameID']).OpponentFinalScore.mean()
# Out:
# 4.017699115044247

# %%
df.loc[df.Team=='Brendan Bottcher'].groupby(cols)['Win'].aggregate(['count','mean'])
# Out:
#                             count      mean
# EndNum EndSituation Hammer
# 1       0           0          38  0.710526
#                     1          74  0.783784
# 2      -3           1           4  0.750000
#        -1           1          24  0.500000
#         0           0           5  0.800000
#                     1          19  0.789474
#         1           0          25  0.760000
#         2           0          22  0.863636
#         3           0           8  1.000000
#         4           0           5  1.000000
# 3      -3           1           2  0.500000
#        -2           0           1  0.000000
#                     1          10  0.200000
#        -1           0           1  1.000000
#                     1          11  0.818182
#         0           0          11  0.454545
#                     1          16  0.812500
#         1           0          18  0.777778
#                     1           7  1.000000
#         2           0          12  0.833333
# ...

# %%
df.loc[df.Team=='Niklas Edin'].groupby(cols)['Win'].aggregate(['count','mean'])
# Out:
#                             count      mean
# EndNum EndSituation Hammer
# 1       0           0          55  0.563636
#                     1          58  0.775862
# 2      -4           1           1  0.000000
#        -3           1           4  0.250000
#        -2           1          10  0.400000
#        -1           1          27  0.592593
#         0           0           8  0.500000
#                     1          10  0.700000
#         1           0          34  0.794118
#         2           0          10  0.800000
#         3           0           4  1.000000
#         4           0           3  1.000000
#         6           0           1  1.000000
# 3      -3           0           1  0.000000
#                     1           2  0.000000
#        -2           0           2  0.000000
#                     1           7  0.714286
#        -1           0           3  0.333333
#                     1          12  0.416667
#         0           0          13  0.307692
# ...
