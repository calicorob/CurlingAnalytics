# %%
# library imports

# db con
from config import get_engine

# data
from analysis import get_scores

# file IO, data manip
import pandas as pd

## lin alg
import numpy as np

# %%
# get data 
df = get_scores(classification='men 8 end')

# %%
# display

df.head()
# Out:
#    PivotedScoreID  GameID  EndNum  EndResult  Hammer  Score  TeamID  EventID  \
# 0          751418   47846       1         -1       1      0  121243     5329
# 1          751420   47846       2          3       1      0  121243     5329
# 2          751422   47846       3         -1       0      3  121243     5329
# 3          751424   47846       4          0       1      3  121243     5329
# 4          751426   47846       5          0       1      3  121243     5329
#
#                   EventName  Year  EndMonth  FinalScore  EndSituation  \
# 0  Red Deer Curling Classic  2018        11           6             0
# 1  Red Deer Curling Classic  2018        11           6            -1
# 2  Red Deer Curling Classic  2018        11           6             2
# 3  Red Deer Curling Classic  2018        11           6             1
# 4  Red Deer Curling Classic  2018        11           6             1
#
#    OpponentTeamID  OpponentFinalScore  Win
# 0          123213                   4  1.0
# 1          123213                   4  1.0
# 2          123213                   4  1.0
# 3          123213                   4  1.0
# 4          123213                   4  1.0

# %%
# scores with hammer

hammer = df.loc[(df.Hammer == 1) & (df.EndResult != 0)].copy()
hammer.head()
# Out:
#    PivotedScoreID  GameID  EndNum  EndResult  Hammer  Score  TeamID  EventID  \
# 0          751418   47846       1         -1       1      0  121243     5329
# 1          751420   47846       2          3       1      0  121243     5329
# 5          751428   47846       6          2       1      3  121243     5329
# 7          751432   47846       8          1       1      5  121243     5329
# 8          909960   58400       1          1       1      0  121243     5329
#
#                   EventName  Year  EndMonth  FinalScore  EndSituation  \
# 0  Red Deer Curling Classic  2018        11           6             0
# 1  Red Deer Curling Classic  2018        11           6            -1
# 5  Red Deer Curling Classic  2018        11           6             1
# 7  Red Deer Curling Classic  2018        11           6             1
# 8  Red Deer Curling Classic  2018        11           1             0
#
#    OpponentTeamID  OpponentFinalScore  Win
# 0          123213                   4  1.0
# 1          123213                   4  1.0
# 5          123213                   4  1.0
# 7          123213                   4  1.0
# 8          127498                   9  0.0

# %%
times_with_hammer = hammer.groupby(['EventID','TeamID'])['TeamID'].count()
times_with_hammer = times_with_hammer.rename('HammerOppurtunities')

# %%
# 2 or more with hammer

conversions = df.loc[(df.Hammer==1) & (df.EndResult >= 2)].copy()
conversions.head()
# Out:
#     PivotedScoreID  GameID  EndNum  EndResult  Hammer  Score  TeamID  EventID  \
# 1           751420   47846       2          3       1      0  121243     5329
# 5           751428   47846       6          2       1      3  121243     5329
# 17         1068344   68955       5          2       1      2  121243     5329
# 24         1226740   79508       6          2       1      1  121243     5329
# 34          887344   56897       2          2       1      0  121252     5329
#
#                    EventName  Year  EndMonth  FinalScore  EndSituation  \
# 1   Red Deer Curling Classic  2018        11           6            -1
# 5   Red Deer Curling Classic  2018        11           6             1
# 17  Red Deer Curling Classic  2018        11           8             0
# 24  Red Deer Curling Classic  2018        11           3            -4
# 34  Red Deer Curling Classic  2018        11           8            -1
#
#     OpponentTeamID  OpponentFinalScore  Win
# 1           123213                   4  1.0
# 5           123213                   4  1.0
# 17          123321                   2  1.0
# 24          123317                   6  0.0
# 34          123716                   7  1.0

# %%
times_converted = conversions.groupby(['EventID','TeamID'])['TeamID'].count()
times_converted = times_converted.rename('HammersConverted')

# %%
# steals 

steals = df.loc[(df.Hammer==1) & (df.EndResult < 0)].copy()

total_steals = steals.groupby(['EventID','TeamID'])['TeamID'].count()
total_steals = total_steals.rename('StealsAllowed')

# %%
stats = pd.concat([times_with_hammer,times_converted,total_steals],axis=1)
stats.head()
# Out:
#                 HammerOppurtunities  HammersConverted  StealsAllowed
# EventID TeamID
# 5271    126196                    7               2.0            4.0
#         126197                   28               7.0           12.0
#         126198                   13               5.0            4.0
#         126199                   17               6.0            4.0
#         126200                   17               5.0            6.0

# %%
stats['ConversionRate'] = (stats['HammersConverted'] / stats['HammerOppurtunities']).replace(np.nan,0)
stats['StealRate'] = (stats['StealsAllowed'] / stats['HammerOppurtunities']).replace(np.nan,0)

# %%
stats
# Out:
#                 HammerOppurtunities  HammersConverted  StealsAllowed  \
# EventID TeamID
# 5271    126196                    7               2.0            4.0
#         126197                   28               7.0           12.0
#         126198                   13               5.0            4.0
#         126199                   17               6.0            4.0
#         126200                   17               5.0            6.0
#         126201                   15               3.0            6.0
#         126202                   10               2.0            3.0
#         126203                   21               6.0            6.0
#         126204                   11               2.0            7.0
#         126205                   16               7.0            3.0
#         126206                   11               5.0            2.0
#         126207                   17               8.0            4.0
#         126208                   13               1.0            2.0
#         126209                   19               4.0           12.0
#         126210                   24              15.0            4.0
#         126219                   18               6.0           10.0
# 5276    124371                   16              11.0            NaN
#         124372                   15               8.0            3.0
#         124373                   18               7.0            1.0
#         124374                   18               9.0            3.0
#         124375                   19              15.0            NaN
#         124376                   17               6.0            3.0
#         124377                   17              11.0            1.0
#         124378                   14               6.0            5.0
#         124379                   11               7.0            2.0
#         124380                   24               9.0            4.0
#         124381                   19               7.0            4.0
#         124382                   16               4.0            4.0
#         124383                   25               9.0            9.0
#         124384                   14               8.0            4.0
# ...                             ...               ...            ...
# 6798    150570                    9               2.0            3.0
#         150571                   13               3.0            2.0
#         150572                   13               6.0            5.0
#         150573                   15              10.0            1.0
#         150574                   11               4.0            1.0
#         150575                   14               4.0            3.0
#         150576                   15               9.0            1.0
#         150577                   13               3.0            5.0
#         150578                   16               4.0            6.0
