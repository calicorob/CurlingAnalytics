# %%
## db con
from config import get_engine

## file IO
import pandas as pd

# %%
## db engine
engine = get_engine(database='Scores')

# %%
## scores
df = pd.read_sql("SELECT * FROM Scores;",con=engine)

# %%
df.head()
# Out:
#    LinescoreID  GameID  EventID  TeamID             EventName Draw  End1  \
# 0            2   89705     3000   66390  Swiss Curling League    1   2.0
# 1            3    2300     3000   66390  Swiss Curling League    4   3.0
# 2            4   55056     3000   66390  Swiss Curling League    6   0.0
# 3            5   11348     3000   66390  Swiss Curling League    8   3.0
# 4            6   95751     3000   66390  Swiss Curling League    9   0.0
#
#    End2  End3  End4     ...       FinalScore         Team  \
# 0   0.0   0.0   0.0     ...                7  Sven Michel
# 1   0.0   0.0   1.0     ...                7  Sven Michel
# 2   3.0   0.0   3.0     ...                7  Sven Michel
# 3   0.0   0.0   2.0     ...                8  Sven Michel
# 4   3.0   0.0   2.0     ...                7  Sven Michel
#
#                                                  URL  \
# 0  https://www.curlingzone.com/event.php?eventid=...
# 1  https://www.curlingzone.com/event.php?eventid=...
# ...

# %%
df.loc[df.GameID == 1]
# Out:
# Empty DataFrame
# Columns: [LinescoreID, GameID, EventID, TeamID, EventName, Draw, End1, End2, End3, End4, End5, End6, End7, End8, End9, End10, End11, End12, Hammer, FinalScore, Team, URL, TeamLink, DrawNum, Year, StartMonth, EndMonth, EventDayStart, EventDayEnd]
# Index: []
#
# [0 rows x 29 columns]
